# %%
### 2024 AUG 31 ###

# %%
##
# conda install -c conda-forge r-optmatch
##

# %%
install.packages("s3")
install.packages("doParallel")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library("terra")
library("dplyr")
library("sf")
#install.packages("s3")
library("s3")

library("sp")
library("foreach")
library("stringr")
library("aws.s3")
#conda install -c conda-forge r-optmatch #r-ggmap r-hrbrthemes r-Hmisc
library("optmatch")
#install.packages("doParallel")
library("doParallel")
# Out:
# terra 1.7.29
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:terra’:
#
#     intersect, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Linking to GEOS 3.11.2, GDAL 3.7.0, PROJ 9.2.0; sf_use_s2() is TRUE
#
# Loading required package: iterators
#
# Loading required package: parallel

# %%
#To test, we define the variables manually. For final version, run the commented out section below
iso3 <-"HND"
gediwk <- 24
mproc <- 1

# %%
#-------------------------------------------------------------------------------
#args = commandArgs(trailingOnly=TRUE)
#if (length(args)==0) {
#  stop("At least one argument must be supplied (input file).n", call.=FALSE)
#} else if (length(args)>=1) {
#  
#  iso3 <- args[1]  #country to process
#  gediwk <- args[2]   #the # of weeks GEDI data to use
#  mproc <- as.integer(args[3])  #the number of cores to use for matching 
#}
#-------------------------------------------------------------------------------

# %%
cat("Step 0: Loading global variables for", iso3,"with wk", gediwk, "data \n")

#f.path <- "/projects/my-public-bucket/GEDI_global_PA_v2/"
f.path <- "s3://maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/"

matching_tifs <- c("wwf_biomes","wwf_ecoreg","lc2000","d2roads", "dcities","dem",
                   "pop_cnt_2000","pop_den_2000","slope", "tt2cities_2000", "wc_prec_1990-1999",
                   "wc_tmax_1990-1999","wc_tavg_1990-1999","wc_tmin_1990-1999" )

ecoreg_key <- read.csv(s3_get(paste(f.path,"wwf_ecoregions_key.csv",sep="")))
#unlink(s3_get(paste(f.path,"wwf_ecoregions_key.csv",sep="")))

allPAs <- readRDS(s3_get(paste(f.path,"WDPA_shapefiles/WDPA_polygons/",iso3,"_PA_poly.rds",sep="")))

MCD12Q1 <- rast(s3_get(paste(f.path,"GEDI_ANCI_PFT_r1000m_EASE2.0_UMD_v1_projection_defined_6933.tif",sep="")))
crs(MCD12Q1)  <- "epsg:6933"

world_region <- rast(s3_get(paste(f.path,"GEDI_ANCI_CONTINENT_r1000m_EASE2.0_UMD_v1_revised_projection_defined_6933.tif",sep="")))
crs(world_region)  <- "epsg:6933"

#s3_get_files(c(paste(f.path,"WDPA_countries/shp/",iso3,".shp",sep=""),
#              paste(f.path,"WDPA_countries/shp/",iso3,".shx",sep=""),
#              paste(f.path,"WDPA_countries/shp/",iso3,".prj",sep=""),
#              paste(f.path,"WDPA_countries/shp/",iso3,".dbf",sep="")),confirm = FALSE)
#adm <- st_read(s3_get(paste(f.path,"WDPA_countries/shp/",iso3,".shp",sep="")))

s3_path <- paste("/vsis3/maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/WDPA_countries/shp/",iso3,".shp",sep="") #Redo this for the gpkg
adm <- st_read(s3_path)
adm_prj <- project(vect(adm), "epsg:6933")

load(s3_get(paste(f.path,"rf_noclimate.RData",sep="")))
#source(s3_get(paste(f.path,"matching_func.R",sep="")))
source(s3_get(paste(f.path,"matching_func_2024.R",sep="")))
# Out:
# Step 0: Loading global variables for HND with wk 24 data
# ℹ s3://maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/wwf_ecoregions_key.csv already exists at /projects/.local/share/R/s3/maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/wwf_ecoregions_key.csv
#
# ℹ s3://maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/WDPA_shapefiles/WDPA_polygons/HND_PA_poly.rds already exists at /projects/.local/share/R/s3/maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/WDPA_shapefiles/WDPA_polygons/HND_PA_poly.rds
#
# ℹ s3://maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/GEDI_ANCI_PFT_r1000m_EASE2.0_UMD_v1_projection_defined_6933.tif already exists at /projects/.local/share/R/s3/maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/GEDI_ANCI_PFT_r1000m_EASE2.0_UMD_v1_projection_defined_6933.tif
#
# ℹ s3://maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/GEDI_ANCI_CONTINENT_r1000m_EASE2.0_UMD_v1_revised_projection_defined_6933.tif already exists at /projects/.local/share/R/s3/maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/GEDI_ANCI_CONTINENT_r1000m_EASE2.0_UMD_v1_revised_projection_defined_6933.tif
# Reading layer `HND' from data source
#   `/vsis3/maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/WDPA_countries/shp/HND.shp'
#   using driver `ESRI Shapefile'
# Simple feature collection with 1 feature and 94 fields
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -89.36379 ymin: 12.97978 xmax: -83.13044 ymax: 17.41865
# Geodetic CRS:  WGS 84
# ℹ s3://maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/rf_noclimate.RData already exists at /projects/.local/share/R/s3/maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/rf_noclimate.RData
#
# ℹ s3://maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/matching_func_2024.R already exists at /projects/.local/share/R/s3/maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/matching_func_2024.R

# %%
#STEP4. Set up spatial points data frames (control + each PA) for point matching
# if (file.exists(paste(f.path,"WDPA_matching_results/",iso3,"_wk",gediwk,"/",iso3,"_matching_output_wk",gediwk,".RDS", sep=""))){
d_control_local <- readRDS(s3_get(paste(f.path,"WDPA_matching_points/",iso3,"/",iso3,"_prepped_control_wk",gediwk,".RDS",sep="")))
d_control_local <- d_control_local[complete.cases(d_control_local), ]  #filter away non-complete cases w/ NA in control set
print(d_control_local[1,])
# Out:
# ℹ s3://maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/WDPA_matching_points/HND/HND_prepped_control_wk24.RDS already exists at /projects/.local/share/R/s3/maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/WDPA_matching_points/HND/HND_prepped_control_wk24.RDS
#                                          wwfbiom
# 1 Tropical & Subtropical Moist Broadleaf Forests
#                                 wwfecoreg     land_cover     d2road    d2city
# 1 Central American Atlantic moist forests l3_agriculture 0.01666666 0.4346133
#   elevation   popcnt   popden    slope  tt2city     prec max_temp mean_temp
# 1       765 45.04786 54.21829 6.657021 269.9006 6071.867 31.06507  23.20684
#   min_temp       lon      lat status UID
# 1 16.37625 -89.11307 15.09587  FALSE   1

# %%
f.path <- "/projects/my-public-bucket/GEDI_global_PA_v2/"
#f.path <- "s3://maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/"

#if(!dir.exists(paste(f.path0,"WDPA_matching_results/",iso3,"_wk",gediwk,"/",sep=""))){
  # cat("Matching result dir does not EXISTS\n")
dir.create(file.path(paste(f.path,"WDPA_matching_results/",iso3,"_wk",gediwk,"/",sep="")))
d_PAs <- list.files(paste(f.path,"WDPA_matching_points/",iso3,"/",iso3,"_testPAs/", sep=""), pattern=paste("wk",gediwk,sep=""), full.names=FALSE)
#} else if (dir.exists(paste(f.path0,"WDPA_matching_results/",iso3,"_wk",gediwk,"/",sep=""))){   #if matching result folder exists, check for any PAs w/o matched results
#  pattern1 = c(paste("wk",gediwk,sep=""),"RDS")
#  matched_PAid <- list.files(paste(f.path0,"WDPA_matching_results/",iso3,"_wk",gediwk,"/",sep=""), full.names = FALSE, pattern=paste0(pattern1, collapse="|"))%>%
#    readr::parse_number() %>% unique()
#  d_PAs <- list.files(paste(f.path0,"WDPA_matching_points/",iso3,"/",iso3,"_testPAs/", sep=""), pattern=paste("wk",gediwk,sep=""), full.names=FALSE)
#  d_PA_id <- d_PAs %>% readr::parse_number()
#  runPA_id <- d_PA_id[!(d_PA_id %in% matched_PAid)]
#  if (length(runPA_id)>0){
#    Pattern2 <-  paste(runPA_id, collapse="|")
#    runPA <-  d_PAs[grepl(Pattern2,d_PAs)]
#    d_PAs <- runPA
#  } else {
#    d_PAs <- NULL
#  }
#}
d_PAs[1]

#Initialize an empty list to store filenames
matching_result_filenames <- c()

registerDoParallel(mproc)
# cat("Parallel processing",getDoParWorkers(),"PAs \n")
startTime <- Sys.time()
#d_PAs <- list.files(paste(f.path,"WDPA_matching_points/",iso3,"/",iso3,"_testPAs/", sep=""), pattern=paste("wk",gediwk,sep=""), full.names=FALSE)

foreach(this_pa=d_PAs,.combine = foreach_rbind, .packages=c('sp','magrittr', 'dplyr','tidyr','optmatch','doParallel')) %dopar% {
  pa <- this_pa
  #id_pa <- pa %>%str_split("_") %>% unlist %>% .[[3]]
  id_pa <- this_pa%>%readr::parse_number() %>% unique() #%>%str_split("_") %>% unlist %>% .[4] #With new files, check where PA ID is in string
  # cat(id_pa, "in",iso3,"\n")
  cat("No.", match(pa,d_PAs),"of total",length(d_PAs),"PAs in ", iso3, "\n" )
  d_pa <- readRDS(paste(f.path,"WDPA_matching_points/",iso3,"/",iso3,"_testPAs/",pa, sep=""))
  # cat(iso3, "pa no.",id_pa, "has",nrow(d_pa)," of treatment \n")
  d_filtered_prop <- tryCatch(propensity_filter(d_pa, d_control_local), error=function(e) return(NA))  #return a df of control and treatment after complete cases and propensity filters are applied
  # cat("Propensity score filtered DF dimension is",dim(d_filtered_prop),"\n")
  d_wocat_all <- tryCatch(filter(d_filtered_prop, status),error=function(e) return(NA))
  d_control_all <- tryCatch(filter(d_filtered_prop, !status),error=function(e) return(NA))
  
  n_control <- dim(d_control_all)[1]
  # ids_all <- d_control_all$UID   #seq(1,n_control)
  ids_all0 <- tryCatch(d_control_all$UID, error=function(e) return(NA))
  ids_all <- d_control_all$UID
  set.seed(125)
  # cat("Using number of cores:",getDoParWorkers(),"\n")
  N <- ceiling(nrow(d_wocat_all)/300)
  l <- tryCatch(split(d_wocat_all, sample(1:N, nrow(d_wocat_all), replace=TRUE)),error=function(e) return(NULL))
  # l <- tryCatch(split(d_wocat_all, (as.numeric(rownames(d_wocat_all))-1) %/% 300),error=function(e) return(0))
  
#  if (length(l)<50 && length(l)>0 ){
  if (length(l)<900 && length(l)>0 ){
    pa_match <- data.frame()
    for (pa_c in 1:length(l)){
      ids_all <- d_control_all$UID
      cat("chunk",pa_c,"of PA", id_pa,"\n")
      
      d_wocat_chunk <- l[[pa_c]]
      # #sample the control dataset to the size of the sample dataset, keep unsampled ids to iterate until full number of matches found
      n_treatment <- dim(d_wocat_chunk)[1]
      
      t <- ifelse(floor(n_control/n_treatment)<=7, ifelse(floor(n_control/n_treatment)<1, 1,floor(n_control/n_treatment)),7)   #floor(n_control/n_treatment))
      n_sample <- round(n_treatment*t)    #now the n_control is 1.4 times the number of n_treatment, 7 will set the if ststament below to flase
      m_all2_out <- data.frame()
      Bscore <- data.frame()
      n_matches <- 0
      tryCatch(
        while(n_matches < n_treatment){
          n_ids <- length(ids_all)
          # cat("n ids",n_ids,"\n")
          if(n_ids > n_sample){
            set.seed(125)
            sample_ids_bar <- sample(ids_all, n_sample)
            sample_ids <- sample(ids_all0, n_sample)
            d_control_sample <- d_control_all[d_control_all$UID %in% sample_ids,]
            ids_all <-setdiff(ids_all, sample_ids_bar)    #ids_all[-sample_ids]
            # cat("protected uid", head(d_wocat_chunk$UID),"\n")
            # All approaches
            new_d <- tryCatch(rbind(d_wocat_chunk,d_control_sample),error=function(e) return(NULL))
            # new_d <- tryCatch(rbind(d_wocat_chunk,d_control_all),error=function(e) return(NULL))
            #create a smaller distance matrix
            m_all <- tryCatch(match_wocat(new_d, pid=id_pa),error=function(e) return(NULL))
            # m_all <- match_wocat(new_d)
            m_all2 <- tryCatch(m_all[1,],error=function(e) return(NULL))
            # m_all2 <- m_all[1,]
            n_matches_temp <- tryCatch(nrow(m_all2$df),error=function(e) return(NULL))
            # n_matches_temp <- nrow(m_all2$df)
            if(!is.null(n_matches_temp)){
              # n_matches <- n_matches + nrow(m_all2$df)
              m_all2$df$pa_id <- rep(id_pa,n_matches_temp)
              m_all2_out <- rbind(m_all2_out, m_all2$df)
              matched_protected <- m_all2$df %>% dplyr::filter(status==TRUE)
              matched_control <- m_all2$df %>% dplyr::filter(status==FALSE)
              cat("matched_protected", nrow(matched_protected),"\n")
              n_matches <- n_matches + nrow(matched_protected)
              d_wocat_chunk <- d_wocat_chunk[-(match(matched_protected$UID,d_wocat_chunk$UID)),]
              # d_control_all <- d_control_all[-(match(matched_control$UID,d_control$UID)),]
            } 
            # ids_all <-setdiff(ids_all, sample_ids)
            ids_all0 <-setdiff(ids_all0, matched_control$UID)
            # else {
            #   n_treatment <- 0  #if not macthes are found in this sampling
            # }
          } else {n_treatment <- n_matches}
        }, error=function(e) return(NULL))
      # ids_all0 <-setdiff(ids_all0, matched_control$UID)
      match_score <- m_all2_out
      cat(table(match_score$status),"\n")
      pa_match <- rbind(pa_match,match_score)
    }
#  } else if (length(l)>=50){
  } else if (length(l)>=900){
    registerDoParallel(3)
    #pa_match <- foreach(pa_c=length(l), .combine = foreach_rbind, .packages=c('sp','magrittr', 'dplyr','tidyr','optmatch','doParallel'))%dopar%{
    pa_match <- foreach(pa_c=1:length(l), .combine = foreach_rbind, .packages=c('sp','magrittr', 'dplyr','tidyr','optmatch','doParallel'))%dopar%{
      # cat("Matching treatment chunk", pa_c, "out of", length(l), "for PA", id_pa,"\n")
      cat("chunk",pa_c,"out of ",length(l), "chunks of PA", id_pa,"\n")
      # cat("head control",head(ids_all0),"\n")
      d_wocat_chunk <- l[[pa_c]]
      # #sample the control dataset to the size of the sample dataset, keep unsampled ids to iterate until full number of matches found
      n_treatment <- dim(d_wocat_chunk)[1]
      # cat( "n control", length(ids_all0),"\n")
      t <- ifelse(floor(n_control/n_treatment)<=7, ifelse(floor(n_control/n_treatment)<1, 1,floor(n_control/n_treatment)),7)   #floor(n_control/n_treatment))
      n_sample <- round(n_treatment*t)    #now the n_control is 1.4 times the number of n_treatment, 7 will set the if ststament below to flase
      m_all2_out <- data.frame()
      Bscore <- data.frame()
      n_matches <- 0
      
      tryCatch(
        while(n_matches < n_treatment){
          
          n_ids <- length(ids_all0)
          # cat("n ids",n_ids,"\n")
          if(n_ids > n_sample){
            set.seed(125)
            sample_ids_bar <- sample(ids_all, n_sample)
            sample_ids <- sample(ids_all0, n_sample)
            d_control_sample <- d_control_all[d_control_all$UID %in% sample_ids,]
            ids_all <-setdiff(ids_all, sample_ids)    #ids_all[-sample_ids]
            # cat("protected uid", head(d_wocat_chunk$UID),"\n")
            # All approaches
            new_d <- tryCatch(rbind(d_wocat_chunk,d_control_sample),error=function(e) return(NULL))
            # new_d <- tryCatch(rbind(d_wocat_chunk,d_control_all),error=function(e) return(NULL))
            
            #create a smaller distance matrix
            m_all <- tryCatch(match_wocat(new_d, pid=id_pa),error=function(e) return(NULL))
            # m_all <- match_wocat(new_d)
            m_all2 <- tryCatch(m_all[1,],error=function(e) return(NULL))
            # m_all2 <- m_all[1,]
            n_matches_temp <- tryCatch(nrow(m_all2$df),error=function(e) return(NULL))
            # n_matches_temp <- nrow(m_all2$df)
            if(!is.null(n_matches_temp)){
              # n_matches <- n_matches + nrow(m_all2$df)
              m_all2$df$pa_id <- rep(id_pa,n_matches_temp)
              m_all2_out <- rbind(m_all2_out, m_all2$df)
              matched_protected <- m_all2$df %>% dplyr::filter(status==TRUE)
              matched_control <- m_all2$df %>% dplyr::filter(status==FALSE)
              cat("matched_protected", nrow(matched_protected),"\n")
              n_matches <- n_matches + nrow(matched_protected)
              d_wocat_chunk <- d_wocat_chunk[-(match(matched_protected$UID,d_wocat_chunk$UID)),]
              # d_control_all <- d_control_all[-(match(matched_control$UID,d_control$UID)),]
              # 
            } 
            ids_all0 <-setdiff(ids_all0, matched_control$UID)
            # cat( "n control", length(ids_all0),"\n")
            
            # else {
            #   n_treatment <- 0  #if not macthes are found in this sampling
            # }
          } else {n_treatment <- n_matches}
        }, error=function(e) return(NULL))
      # ids_all0 <-setdiff(ids_all0, matched_control$UID)
      match_score <- m_all2_out
      # cat(table(match_score$status),"\n")
      return(match_score)
    }
    stopImplicitCluster()
  } else{
    pa_match <- NULL
  }

    output_filename <- paste(f.path,"WDPA_matching_results/",iso3,"_wk",gediwk,"/",iso3,"_pa_", id_pa,"_matching_results_wk",gediwk,".RDS", sep="")
    saveRDS(pa_match, file=output_filename)
  
  # Append the filename to the list
  output_filenames <- c(output_filenames, output_filename)
  print(output_filename)
                                       
  cat("Results exported for PA", id_pa, "\n")
  rm(pa_match)
  return(NULL)
}

tElapsed <- Sys.time()-startTime
# cat(tElapsed, "for matching all PAs in", iso3,"\n")
stopImplicitCluster()
cat("Done matching for",iso3,". Finishing...\n")

# Write the list of filenames to a CSV file
write.csv(output_filenames, file=paste(f.path,"WDPA_matching_results/",iso3,"_wk",gediwk,"_matching_result_filenames.csv", sep=""), row.names = FALSE, col.names = FALSE)
# Out:
# [1] "HND_prepped_pa_102215_wk24.RDS"
# No. 1 of total 88 PAs in  HND
# chunk 1 of PA 102215
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_102215_matching_results_wk24.RDS"
# Results exported for PA 102215
# No. 2 of total 88 PAs in  HND
# chunk 1 of PA 102216
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_102216_matching_results_wk24.RDS"
# Results exported for PA 102216
# No. 3 of total 88 PAs in  HND
# chunk 1 of PA 102217
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_102217_matching_results_wk24.RDS"
# Results exported for PA 102217
# No. 4 of total 88 PAs in  HND
# chunk 1 of PA 102221
# matched_protected 58
# matched_protected 84
# 142 142
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_102221_matching_results_wk24.RDS"
# Results exported for PA 102221
# No. 5 of total 88 PAs in  HND
# chunk 1 of PA 102234
# matched_protected 154
# 154 154
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_102234_matching_results_wk24.RDS"
# Results exported for PA 102234
# No. 6 of total 88 PAs in  HND
# chunk 1 of PA 18804
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18804_matching_results_wk24.RDS"
# Results exported for PA 18804
# No. 7 of total 88 PAs in  HND
# chunk 1 of PA 18805
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18805_matching_results_wk24.RDS"
# Results exported for PA 18805
# No. 8 of total 88 PAs in  HND
# chunk 1 of PA 18807
# matched_protected 164
# 164 164
# chunk 2 of PA 18807
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18807_matching_results_wk24.RDS"
# Results exported for PA 18807
# No. 9 of total 88 PAs in  HND
# chunk 1 of PA 18808
# matched_protected 158
# 158 158
# chunk 2 of PA 18808
# matched_protected 147
# 147 147
# chunk 3 of PA 18808
# matched_protected 146
# 146 146
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18808_matching_results_wk24.RDS"
# Results exported for PA 18808
# No. 10 of total 88 PAs in  HND
# chunk 1 of PA 18809
# matched_protected 108
# matched_protected 191
# 299 299
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18809_matching_results_wk24.RDS"
# Results exported for PA 18809
# No. 11 of total 88 PAs in  HND
# chunk 1 of PA 18810
# matched_protected 34
# matched_protected 213
# 247 247
# chunk 2 of PA 18810
# matched_protected 34
# matched_protected 208
# 242 242
# chunk 3 of PA 18810
# matched_protected 6
# matched_protected 24
# 30 30
# chunk 4 of PA 18810
# matched_protected 30
# matched_protected 206
# 236 236
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18810_matching_results_wk24.RDS"
# Results exported for PA 18810
# No. 12 of total 88 PAs in  HND
# chunk 1 of PA 18811
# matched_protected 156
# 156 156
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18811_matching_results_wk24.RDS"
# Results exported for PA 18811
# No. 13 of total 88 PAs in  HND
# chunk 1 of PA 18812
# matched_protected 112
# matched_protected 3
# 115 115
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18812_matching_results_wk24.RDS"
# Results exported for PA 18812
# No. 14 of total 88 PAs in  HND
# chunk 1 of PA 18813
# matched_protected 106
# matched_protected 10
# 116 116
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18813_matching_results_wk24.RDS"
# Results exported for PA 18813
# No. 15 of total 88 PAs in  HND
# chunk 1 of PA 18816
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18816_matching_results_wk24.RDS"
# Results exported for PA 18816
# No. 16 of total 88 PAs in  HND
# chunk 1 of PA 18823
# matched_protected 28
# 28 28
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18823_matching_results_wk24.RDS"
# Results exported for PA 18823
# No. 17 of total 88 PAs in  HND
# chunk 1 of PA 18825
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18825_matching_results_wk24.RDS"
# Results exported for PA 18825
# No. 18 of total 88 PAs in  HND
# chunk 1 of PA 18826
# matched_protected 82
# matched_protected 178
# 260 260
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18826_matching_results_wk24.RDS"
# Results exported for PA 18826
# No. 19 of total 88 PAs in  HND
# chunk 1 of PA 18827
# matched_protected 6
# matched_protected 38
# 44 44
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18827_matching_results_wk24.RDS"
# Results exported for PA 18827
# No. 20 of total 88 PAs in  HND
# chunk 1 of PA 18828
# matched_protected 8
# 8 8
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18828_matching_results_wk24.RDS"
# Results exported for PA 18828
# No. 21 of total 88 PAs in  HND
# chunk 1 of PA 18830
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18830_matching_results_wk24.RDS"
# Results exported for PA 18830
# No. 22 of total 88 PAs in  HND
# chunk 1 of PA 18831
# matched_protected 118
# 118 118
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18831_matching_results_wk24.RDS"
# Results exported for PA 18831
# No. 23 of total 88 PAs in  HND
# chunk 1 of PA 18832
# matched_protected 204
# 204 204
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18832_matching_results_wk24.RDS"
# Results exported for PA 18832
# No. 24 of total 88 PAs in  HND
# chunk 1 of PA 18839
# matched_protected 20
# 20 20
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18839_matching_results_wk24.RDS"
# Results exported for PA 18839
# No. 25 of total 88 PAs in  HND
# chunk 1 of PA 18841
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18841_matching_results_wk24.RDS"
# Results exported for PA 18841
# No. 26 of total 88 PAs in  HND
# chunk 1 of PA 18843
# matched_protected 122
# 122 122
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18843_matching_results_wk24.RDS"
# Results exported for PA 18843
# No. 27 of total 88 PAs in  HND
# chunk 1 of PA 18844
# matched_protected 24
# matched_protected 99
# 123 123
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18844_matching_results_wk24.RDS"
# Results exported for PA 18844
# No. 28 of total 88 PAs in  HND
# chunk 1 of PA 18845
# matched_protected 240
# 240 240
# chunk 2 of PA 18845
# matched_protected 226
# 226 226
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18845_matching_results_wk24.RDS"
# Results exported for PA 18845
# No. 29 of total 88 PAs in  HND
# chunk 1 of PA 18847
# matched_protected 114
# matched_protected 156
# 270 270
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_18847_matching_results_wk24.RDS"
# Results exported for PA 18847
# No. 30 of total 88 PAs in  HND
# chunk 1 of PA 200
# matched_protected 109
# matched_protected 129
# 238 238
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_200_matching_results_wk24.RDS"
# Results exported for PA 200
# No. 31 of total 88 PAs in  HND
# chunk 1 of PA 201
# matched_protected 322
# 322 322
# chunk 2 of PA 201
# matched_protected 294
# matched_protected 2
# 296 296
# chunk 3 of PA 201
# matched_protected 268
# matched_protected 4
# 272 272
# chunk 4 of PA 201
# matched_protected 305
# matched_protected 5
# 310 310
# chunk 5 of PA 201
# matched_protected 83
# matched_protected 216
# 299 299
# chunk 6 of PA 201
# matched_protected 71
# 71 71
# chunk 7 of PA 201
# matched_protected 63
# 63 63
# chunk 8 of PA 201
# matched_protected 71
# 71 71
# chunk 9 of PA 201
# matched_protected 61
# matched_protected 2
# 63 63
# chunk 10 of PA 201
# matched_protected 52
# 52 52
# chunk 11 of PA 201
# matched_protected 72
# matched_protected 1
# 73 73
# chunk 12 of PA 201
# matched_protected 58
# matched_protected 2
# 60 60
# chunk 13 of PA 201
# matched_protected 65
# 65 65
# chunk 14 of PA 201
# matched_protected 58
# 58 58
# chunk 15 of PA 201
# matched_protected 74
# matched_protected 8
# 82 82
# chunk 16 of PA 201
# matched_protected 56
# matched_protected 5
# 61 61
# chunk 17 of PA 201
# matched_protected 55
# matched_protected 1
# 56 56
# chunk 18 of PA 201
# matched_protected 59
# 59 59
# chunk 19 of PA 201
# matched_protected 63
# 63 63
# chunk 20 of PA 201
# matched_protected 50
# 50 50
# chunk 21 of PA 201
# matched_protected 61
# 61 61
# chunk 22 of PA 201
# matched_protected 53
# 53 53
# chunk 23 of PA 201
# matched_protected 51
# 51 51
# chunk 24 of PA 201
# matched_protected 66
# 66 66
# chunk 25 of PA 201
# matched_protected 49
# 49 49
# chunk 26 of PA 201
# matched_protected 58
# 58 58
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_201_matching_results_wk24.RDS"
# Results exported for PA 201
# No. 32 of total 88 PAs in  HND
# chunk 1 of PA 2196
# matched_protected 147
# 147 147
# chunk 2 of PA 2196
# matched_protected 148
# 148 148
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_2196_matching_results_wk24.RDS"
# Results exported for PA 2196
# No. 33 of total 88 PAs in  HND
# chunk 1 of PA 23305
# matched_protected 55
# 55 55
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_23305_matching_results_wk24.RDS"
# Results exported for PA 23305
# No. 34 of total 88 PAs in  HND
# chunk 1 of PA 23306
# matched_protected 169
# 169 169
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_23306_matching_results_wk24.RDS"
# Results exported for PA 23306
# No. 35 of total 88 PAs in  HND
# chunk 1 of PA 23307
# matched_protected 4
# 4 4
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_23307_matching_results_wk24.RDS"
# Results exported for PA 23307
# No. 36 of total 88 PAs in  HND
# chunk 1 of PA 23308
# matched_protected 17
# matched_protected 18
# 35 35
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_23308_matching_results_wk24.RDS"
# Results exported for PA 23308
# No. 37 of total 88 PAs in  HND
# chunk 1 of PA 302118
# matched_protected 2
# matched_protected 68
# 70 70
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_302118_matching_results_wk24.RDS"
# Results exported for PA 302118
# No. 38 of total 88 PAs in  HND
# chunk 1 of PA 302119
# matched_protected 38
# 38 38
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_302119_matching_results_wk24.RDS"
# Results exported for PA 302119
# No. 39 of total 88 PAs in  HND
# chunk 1 of PA 302120
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_302120_matching_results_wk24.RDS"
# Results exported for PA 302120
# No. 40 of total 88 PAs in  HND
# chunk 1 of PA 30621
# matched_protected 210
# 210 210
# chunk 2 of PA 30621
# matched_protected 184
# 184 184
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_30621_matching_results_wk24.RDS"
# Results exported for PA 30621
# No. 41 of total 88 PAs in  HND
# chunk 1 of PA 30625
# matched_protected 225
# 225 225
# chunk 2 of PA 30625
# matched_protected 210
# 210 210
# chunk 3 of PA 30625
# matched_protected 198
# 198 198
# chunk 4 of PA 30625
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_30625_matching_results_wk24.RDS"
# Results exported for PA 30625
# No. 42 of total 88 PAs in  HND
# chunk 1 of PA 30627
#
# chunk 2 of PA 30627
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_30627_matching_results_wk24.RDS"
# Results exported for PA 30627
# No. 43 of total 88 PAs in  HND
# chunk 1 of PA 342379
# matched_protected 55
# 55 55
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_342379_matching_results_wk24.RDS"
# Results exported for PA 342379
# No. 44 of total 88 PAs in  HND
# chunk 1 of PA 34629
# matched_protected 1
# 1 1
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_34629_matching_results_wk24.RDS"
# Results exported for PA 34629
# No. 45 of total 88 PAs in  HND
# chunk 1 of PA 36051
# matched_protected 13
# 13 13
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_36051_matching_results_wk24.RDS"
# Results exported for PA 36051
# No. 46 of total 88 PAs in  HND
# chunk 1 of PA 36053
# matched_protected 169
# 169 169
# chunk 2 of PA 36053
# matched_protected 154
# matched_protected 7
# 161 161
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_36053_matching_results_wk24.RDS"
# Results exported for PA 36053
# No. 47 of total 88 PAs in  HND
# chunk 1 of PA 40997
# matched_protected 290
# 290 290
# chunk 2 of PA 40997
# matched_protected 300
# 300 300
# chunk 3 of PA 40997
# matched_protected 287
# 287 287
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_40997_matching_results_wk24.RDS"
# Results exported for PA 40997
# No. 48 of total 88 PAs in  HND
# chunk 1 of PA 41001
# matched_protected 4
# 4 4
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41001_matching_results_wk24.RDS"
# Results exported for PA 41001
# No. 49 of total 88 PAs in  HND
# chunk 1 of PA 41011
# matched_protected 82
# 82 82
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41011_matching_results_wk24.RDS"
# Results exported for PA 41011
# No. 50 of total 88 PAs in  HND
# chunk 1 of PA 41013
# matched_protected 285
# 285 285
# chunk 2 of PA 41013
# matched_protected 102
# 102 102
# chunk 3 of PA 41013
# matched_protected 103
# 103 103
# chunk 4 of PA 41013
# matched_protected 99
# 99 99
# chunk 5 of PA 41013
#
# chunk 6 of PA 41013
#
# chunk 7 of PA 41013
#
# chunk 8 of PA 41013
#
# chunk 9 of PA 41013
#
# chunk 10 of PA 41013
#
# chunk 11 of PA 41013
#
# chunk 12 of PA 41013
#
# chunk 13 of PA 41013
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41013_matching_results_wk24.RDS"
# Results exported for PA 41013
# No. 51 of total 88 PAs in  HND
# chunk 1 of PA 41014
# matched_protected 316
# 316 316
# chunk 2 of PA 41014
# matched_protected 279
# matched_protected 5
# 284 284
# chunk 3 of PA 41014
# matched_protected 255
# matched_protected 1
# 256 256
# chunk 4 of PA 41014
# matched_protected 287
# 287 287
# chunk 5 of PA 41014
# matched_protected 75
# matched_protected 215
# 290 290
# chunk 6 of PA 41014
# matched_protected 75
# 75 75
# chunk 7 of PA 41014
# matched_protected 57
# matched_protected 11
# 68 68
# chunk 8 of PA 41014
# matched_protected 74
# 74 74
# chunk 9 of PA 41014
# matched_protected 67
# matched_protected 10
# 77 77
# chunk 10 of PA 41014
# matched_protected 45
# 45 45
# chunk 11 of PA 41014
# matched_protected 70
# matched_protected 4
# 74 74
# chunk 12 of PA 41014
# matched_protected 45
# 45 45
# chunk 13 of PA 41014
# matched_protected 49
# matched_protected 1
# 50 50
# chunk 14 of PA 41014
# matched_protected 64
# matched_protected 1
# 65 65
# chunk 15 of PA 41014
# matched_protected 57
# matched_protected 3
# 60 60
# chunk 16 of PA 41014
# matched_protected 53
# matched_protected 2
# matched_protected 1
# 56 56
# chunk 17 of PA 41014
# matched_protected 46
# matched_protected 1
# 47 47
# chunk 18 of PA 41014
# matched_protected 53
# 53 53
# chunk 19 of PA 41014
# matched_protected 74
# 74 74
# chunk 20 of PA 41014
# matched_protected 57
# 57 57
# chunk 21 of PA 41014
# matched_protected 54
# 54 54
# chunk 22 of PA 41014
# matched_protected 61
# matched_protected 5
# 66 66
# chunk 23 of PA 41014
# matched_protected 57
# 57 57
# chunk 24 of PA 41014
# matched_protected 71
# 71 71
# chunk 25 of PA 41014
# matched_protected 71
# matched_protected 211
# 282 282
# chunk 26 of PA 41014
# matched_protected 53
# 53 53
# chunk 27 of PA 41014
# matched_protected 61
# 61 61
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41014_matching_results_wk24.RDS"
# Results exported for PA 41014
# No. 52 of total 88 PAs in  HND
# chunk 1 of PA 41019
# matched_protected 27
# 27 27
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41019_matching_results_wk24.RDS"
# Results exported for PA 41019
# No. 53 of total 88 PAs in  HND
# chunk 1 of PA 41021
# matched_protected 15
# 15 15
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41021_matching_results_wk24.RDS"
# Results exported for PA 41021
# No. 54 of total 88 PAs in  HND
# chunk 1 of PA 41022
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41022_matching_results_wk24.RDS"
# Results exported for PA 41022
# No. 55 of total 88 PAs in  HND
# chunk 1 of PA 41024
# matched_protected 102
# 102 102
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41024_matching_results_wk24.RDS"
# Results exported for PA 41024
# No. 56 of total 88 PAs in  HND
# chunk 1 of PA 41026
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41026_matching_results_wk24.RDS"
# Results exported for PA 41026
# No. 57 of total 88 PAs in  HND
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41027_matching_results_wk24.RDS"
# Results exported for PA 41027
# No. 58 of total 88 PAs in  HND
# chunk 1 of PA 41037
# matched_protected 52
# 52 52
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41037_matching_results_wk24.RDS"
# Results exported for PA 41037
# No. 59 of total 88 PAs in  HND
# chunk 1 of PA 41043
# matched_protected 2
# 2 2
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41043_matching_results_wk24.RDS"
# Results exported for PA 41043
# No. 60 of total 88 PAs in  HND
# chunk 1 of PA 41044
#
# chunk 2 of PA 41044
# matched_protected 162
# 162 162
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41044_matching_results_wk24.RDS"
# Results exported for PA 41044
# No. 61 of total 88 PAs in  HND
# chunk 1 of PA 41045
# matched_protected 276
# 276 276
# chunk 2 of PA 41045
# matched_protected 269
# 269 269
# chunk 3 of PA 41045
# matched_protected 29
# 29 29
# chunk 4 of PA 41045
# matched_protected 23
# 23 23
# chunk 5 of PA 41045
# matched_protected 31
# 31 31
# chunk 6 of PA 41045
# matched_protected 47
# 47 47
# chunk 7 of PA 41045
# matched_protected 32
# 32 32
# chunk 8 of PA 41045
# matched_protected 34
# 34 34
# chunk 9 of PA 41045
# matched_protected 43
# 43 43
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_41045_matching_results_wk24.RDS"
# Results exported for PA 41045
# No. 62 of total 88 PAs in  HND
# chunk 1 of PA 5002
# matched_protected 304
# 304 304
# chunk 2 of PA 5002
# matched_protected 291
# 291 291
# chunk 3 of PA 5002
# matched_protected 285
# 285 285
# chunk 4 of PA 5002
# matched_protected 283
# matched_protected 6
# 289 289
# chunk 5 of PA 5002
# matched_protected 77
# 77 77
# chunk 6 of PA 5002
# matched_protected 85
# 85 85
# chunk 7 of PA 5002
# matched_protected 72
# 72 72
# chunk 8 of PA 5002
# matched_protected 68
# 68 68
# chunk 9 of PA 5002
# matched_protected 64
# 64 64
# chunk 10 of PA 5002
# matched_protected 59
# 59 59
# chunk 11 of PA 5002
# matched_protected 72
# 72 72
# chunk 12 of PA 5002
# matched_protected 73
# matched_protected 199
# 272 272
# chunk 13 of PA 5002
# matched_protected 62
# 62 62
# chunk 14 of PA 5002
# matched_protected 79
# 79 79
# chunk 15 of PA 5002
# matched_protected 58
# matched_protected 4
# 62 62
# chunk 16 of PA 5002
# matched_protected 76
# 76 76
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_5002_matching_results_wk24.RDS"
# Results exported for PA 5002
# No. 63 of total 88 PAs in  HND
# chunk 1 of PA 555582977
# matched_protected 21
# 21 21
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582977_matching_results_wk24.RDS"
# Results exported for PA 555582977
# No. 64 of total 88 PAs in  HND
# chunk 1 of PA 555582978
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582978_matching_results_wk24.RDS"
# Results exported for PA 555582978
# No. 65 of total 88 PAs in  HND
# chunk 1 of PA 555582980
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582980_matching_results_wk24.RDS"
# Results exported for PA 555582980
# No. 66 of total 88 PAs in  HND
# chunk 1 of PA 555582981
# matched_protected 246
# 246 246
# chunk 2 of PA 555582981
# matched_protected 241
# 241 241
# chunk 3 of PA 555582981
# matched_protected 237
# 237 237
# chunk 4 of PA 555582981
# matched_protected 234
# 234 234
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582981_matching_results_wk24.RDS"
# Results exported for PA 555582981
# No. 67 of total 88 PAs in  HND
# chunk 1 of PA 555582982
# matched_protected 191
# 191 191
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582982_matching_results_wk24.RDS"
# Results exported for PA 555582982
# No. 68 of total 88 PAs in  HND
# chunk 1 of PA 555582985
#
# chunk 2 of PA 555582985
#
# chunk 3 of PA 555582985
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582985_matching_results_wk24.RDS"
# Results exported for PA 555582985
# No. 69 of total 88 PAs in  HND
# chunk 1 of PA 555582988
# matched_protected 224
# 224 224
# chunk 2 of PA 555582988
# matched_protected 215
# 215 215
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582988_matching_results_wk24.RDS"
# Results exported for PA 555582988
# No. 70 of total 88 PAs in  HND
# chunk 1 of PA 555582989
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582989_matching_results_wk24.RDS"
# Results exported for PA 555582989
# No. 71 of total 88 PAs in  HND
# chunk 1 of PA 555582990
# matched_protected 207
# 207 207
# chunk 2 of PA 555582990
# matched_protected 11
# 11 11
# chunk 3 of PA 555582990
# matched_protected 13
# matched_protected 10
# 23 23
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582990_matching_results_wk24.RDS"
# Results exported for PA 555582990
# No. 72 of total 88 PAs in  HND
# chunk 1 of PA 555582991
# matched_protected 292
# 292 292
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582991_matching_results_wk24.RDS"
# Results exported for PA 555582991
# No. 73 of total 88 PAs in  HND
# chunk 1 of PA 555582992
# matched_protected 281
# 281 281
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582992_matching_results_wk24.RDS"
# Results exported for PA 555582992
# No. 74 of total 88 PAs in  HND
# chunk 1 of PA 555582993
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555582993_matching_results_wk24.RDS"
# Results exported for PA 555582993
# No. 75 of total 88 PAs in  HND
# chunk 1 of PA 555625660
# matched_protected 252
# 252 252
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555625660_matching_results_wk24.RDS"
# Results exported for PA 555625660
# No. 76 of total 88 PAs in  HND
# chunk 1 of PA 555625661
# matched_protected 29
# 29 29
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555625661_matching_results_wk24.RDS"
# Results exported for PA 555625661
# No. 77 of total 88 PAs in  HND
# chunk 1 of PA 555635544
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555635544_matching_results_wk24.RDS"
# Results exported for PA 555635544
# No. 78 of total 88 PAs in  HND
# chunk 1 of PA 555635546
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555635546_matching_results_wk24.RDS"
# Results exported for PA 555635546
# No. 79 of total 88 PAs in  HND
# chunk 1 of PA 555635547
# matched_protected 1
# matched_protected 1
# 2 2
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555635547_matching_results_wk24.RDS"
# Results exported for PA 555635547
# No. 80 of total 88 PAs in  HND
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555637328_matching_results_wk24.RDS"
# Results exported for PA 555637328
# No. 81 of total 88 PAs in  HND
# chunk 1 of PA 555697536
# matched_protected 4
# 4 4
# chunk 2 of PA 555697536
# matched_protected 34
# 34 34
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555697536_matching_results_wk24.RDS"
# Results exported for PA 555697536
# No. 82 of total 88 PAs in  HND
# chunk 1 of PA 555697537
# matched_protected 1
# 1 1
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555697537_matching_results_wk24.RDS"
# Results exported for PA 555697537
# No. 83 of total 88 PAs in  HND
# chunk 1 of PA 555697538
# matched_protected 2
# 2 2
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_555697538_matching_results_wk24.RDS"
# Results exported for PA 555697538
# No. 84 of total 88 PAs in  HND
# chunk 1 of PA 62046
# matched_protected 289
# 289 289
# chunk 2 of PA 62046
# matched_protected 277
# 277 277
# chunk 3 of PA 62046
# matched_protected 133
# 133 133
# chunk 4 of PA 62046
# matched_protected 131
# 131 131
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_62046_matching_results_wk24.RDS"
# Results exported for PA 62046
# No. 85 of total 88 PAs in  HND
# chunk 1 of PA 62051
# matched_protected 108
# 108 108
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_62051_matching_results_wk24.RDS"
# Results exported for PA 62051
# No. 86 of total 88 PAs in  HND
# chunk 1 of PA 62052
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_62052_matching_results_wk24.RDS"
# Results exported for PA 62052
# No. 87 of total 88 PAs in  HND
# chunk 1 of PA 62055
#
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_62055_matching_results_wk24.RDS"
# Results exported for PA 62055
# No. 88 of total 88 PAs in  HND
# chunk 1 of PA 95337
# matched_protected 15
# 15 15
# [1] "/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24/HND_pa_95337_matching_results_wk24.RDS"
# Results exported for PA 95337
# NULL
# Done matching for HND . Finishing...

# %%
##
matching_results <- list.files("/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_matching_results/HND_wk24", full.names=T)
length(matching_results)
##
for(i in 1:length(matching_results)){
    m_data <- readRDS(matching_results[i])
    print(nrow(m_data))
    }
# Out:
# [1] 88
# [1] 0
# [1] 0
# [1] 0
# [1] 284
# [1] 308
# [1] 0
# [1] 0
# [1] 328
# [1] 902
# [1] 598
# [1] 1510
# [1] 312
# [1] 230
# [1] 232
# [1] 0
# [1] 56
# [1] 0
# [1] 520
# [1] 88
# [1] 16
# [1] 0
# [1] 236
# [1] 408
# [1] 40
# [1] 0
# [1] 244
# [1] 246
# [1] 932
# [1] 540
# [1] 476
# [1] 5568
# [1] 590
# [1] 110
# [1] 338
# [1] 8
# [1] 70
# [1] 140
# [1] 76
# [1] 0
# [1] 788
# [1] 1266
# [1] 0
# [1] 110
# [1] 2
# [1] 26
# [1] 660
# [1] 1754
# [1] 8
# [1] 164
# [1] 1178
# [1] 5994
# [1] 54
# [1] 30
# [1] 0
# [1] 204
# [1] 0
# NULL
# [1] 104
# [1] 4
# [1] 324
# [1] 1568
# [1] 4434
# [1] 42
# [1] 0
# [1] 0
# [1] 1916
# [1] 382
# [1] 0
# [1] 878
# [1] 0
# [1] 482
# [1] 584
# [1] 562
# [1] 0
# [1] 504
# [1] 58
# [1] 0
# [1] 0
# [1] 4
# NULL
# [1] 76
# [1] 2
# [1] 4
# [1] 1660
# [1] 216
# [1] 0
# [1] 0
# [1] 30
