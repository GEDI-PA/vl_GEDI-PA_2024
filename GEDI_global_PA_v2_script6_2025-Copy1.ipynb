# %%
## calculating GEDI summary stats from extracted dataframes

# %%
install.packages("s3")
#install.packages("doParallel")
#install.packages("RItools")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library("terra")
library("dplyr")
library("sf")
library("s3")
library("sp")
library("foreach")
library("stringr")
library("aws.s3")
#library("doParallel")
#library("RItools")
# Out:
# terra 1.7.29
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:terra’:
#
#     intersect, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Linking to GEOS 3.11.2, GDAL 3.7.0, PROJ 9.2.0; sf_use_s2() is TRUE

# %%
#f.path <- "s3://maap-ops-workspace/shared/leitoldv/GEDI_global_PA_v2/"
f.path <- "/projects/my-public-bucket/GEDI_global_PA_v2/"
iso3 <- "UGA"
gediwk <- 24
#source(s3_get(paste(f.path,"matching_func.R",sep="")))
source(paste(f.path,"vl_GEDI-PA_2024/matching_func_2024.R",sep=""))

# %%
## STEP6: [FIGURE 4B] Calculating per pa summary stats, 1 pa per row, contain shot#/PA---------------------------- 
cat(paste("Step 6: calculating per pa summary stats for", iso3,"\n"))

gedi_paf <- list.files(paste(f.path,"WDPA_extract/",iso3,"_wk",gediwk,sep=""), pattern=".RDS", full.names = TRUE)
length(gedi_paf)
# Out:
# Step 6: calculating per pa summary stats for UGA
# [1] 311

# %%
for (this_paf in gedi_paf){
#for (this_paf in rev(gedi_paf)){
  cat(paste("calculating summary stats for PA",this_paf,"\n"))
  pa_metrics <- readRDS(this_paf) %>% unique()
  if (length(table(pa_metrics$status))<2) {
    cat(iso3, this_paf, "has 0 protected or treatment \n")
  } else if (table(pa_metrics$status)[1]!=0 && table(pa_metrics$status)[2]!=0) {
    #filter the datafrme by number of shots in each cell, which is equivalent to the number of occurence of each unique UID code
##    tt <- table(pa_metrics$UID)
##    qcellid <- table(pa_metrics$UID)[tt>5] %>% names()
##    pa_metrics_filtered <- pa_metrics %>% dplyr::filter(UID %in% qcellid)
    #calc summary stats for each country 
    #pa_stats_summary <- pa_metrics_filtered %>%
    pa_stats_summary <- pa_metrics %>%
      group_by(status) %>% 
      dplyr::mutate(pa_id=as.character(pa_id)) %>%
      dplyr::summarise(pa_id=na.omit(unique(pa_id)),
                       count=length(rh98),
                       meanrh98=mean(rh98, na.rm=TRUE), sdrh98=sd(rh98, na.rm=TRUE),
                       meanagbd=mean(agbd, na.rm=TRUE), sdagbd=sd(agbd, na.rm=TRUE),
                       wwfbiom=getmode(wwfbiom), wwfecoreg=getmode(wwfecoreg),
                       REGION=getmode(region), PFT=getmode(pft)) %>% 
      tidyr::pivot_wider(names_from=status, values_from= setdiff(names(.),c("pa_id", "status")))
    #writeLine to a large txt file where world pas stats are
    pa_stats_summary$iso3 <- iso3

/projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40352_gedi_wk_24_conti_biome_TSGSS.RDS has 0 protected or treatment
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40353_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40356_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40362_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40368_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40377_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40378_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40381_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40382_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40389_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40390_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40393_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40394_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40395_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40396_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40404_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40417_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40422_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40429_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40431_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40432_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40436_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40445_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40446_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40448_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40463_gedi_wk_24_conti_biome_TSMBF+TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40470_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40471_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40472_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40475_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40476_gedi_wk_24_conti_biome_TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40481_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40482_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40483_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40484_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# ...
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40517_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40520_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40521_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40523_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40525_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40535_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40538_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40543_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40551_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40552_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40555_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40560_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40562_gedi_wk_24_conti_biome_TSGSS.RDS
# UGA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40562_gedi_wk_24_conti_biome_TSGSS.RDS has 0 protected or treatment
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40576_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40578_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40580_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40588_gedi_wk_24_conti_biome_TSGSS+TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40589_gedi_wk_24_conti_biome_TSMBF+TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40590_gedi_wk_24_conti_biome_TSMBF+TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40591_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40592_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40593_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40595_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40596_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40597_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40598_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40600_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40601_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40602_gedi_wk_24_conti_biome_TSGSS+TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40603_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40604_gedi_wk_24_conti_biome_TSGSS+TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40608_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40609_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40614_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40615_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40616_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40617_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40619_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40622_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40626_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40630_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40635_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40642_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40648_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40649_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40651_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40652_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40653_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40692_gedi_wk_24_conti_biome_TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40701_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40703_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40704_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40705_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40707_gedi_wk_24_conti_biome_TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40722_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_555549367_gedi_wk_24_conti_biome_TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_61609_gedi_wk_24_conti_biome_TSGSS+TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_64633_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_64669_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_64671_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_64673_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_64700_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_68242_gedi_wk_24_conti_biome_TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_7930_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_7931_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_7934_gedi_wk_24_conti_biome_TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_902529_gedi_wk_24_conti_biome_TSMBF+TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_902980_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_902982_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_902984_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_9186_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_956_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_957_gedi_wk_24_conti_biome_TSGSS.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# calculating summary stats for PA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_958_gedi_wk_24_conti_biome_TSGSS+TSMBF.RDS
# [1] "pa_stats_summary file exists so appending to existing file"
# Done summarizing pa-level stats for region UGA

# %%
for (this_paf in gedi_paf){
  pa_metrics <- readRDS(this_paf) %>% unique()
  if (length(table(pa_metrics$status))<2) {
    cat(iso3, this_paf, "has 0 protected or treatment \n")
  } else if (table(pa_metrics$status)[1]!=0 && table(pa_metrics$status)[2]!=0) {
#--------
    lon_0 <- pa_metrics[pa_metrics$status==0,"lon_lowestmode"]
    lat_0 <- pa_metrics[pa_metrics$status==0,"lat_lowestmode"]
    lon_1 <- pa_metrics[pa_metrics$status==1,"lon_lowestmode"]
    lat_1 <- pa_metrics[pa_metrics$status==1,"lat_lowestmode"]
    
    plot(vect(cbind(lon_0,lat_0), type="points", atts=NULL), pch=".", main=unique(pa_metrics$pa_id))
    points(vect(cbind(lon_1,lat_1), type="points", atts=NULL), pch=".", col="red")
#--------
    }
}
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# UGA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_313110_gedi_wk_24_conti_biome_TSGSS.RDS has 0 protected or treatment
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# UGA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40352_gedi_wk_24_conti_biome_TSGSS.RDS has 0 protected or treatment
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# UGA /projects/my-public-bucket/GEDI_global_PA_v2/WDPA_extract/UGA_wk24/UGA_pa_40562_gedi_wk_24_conti_biome_TSGSS.RDS has 0 protected or treatment
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
